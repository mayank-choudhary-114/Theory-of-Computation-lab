# %% [markdown]
# PDA IMPLEMENTATION USING STACK AND DICTIONARIES

# %% [markdown]
# PDA accepting strings of type a^nb^n where n>=1

# %%
#test case:1 acceptable String
pda=dict()

pda[(0,'a')]=1
pda[(0,'b')]=4
pda[(0,'z')]=4
pda[(1,'a')]=1
pda[(1,'b')]=2
pda[(2,'a')]=4
pda[(2,'b')]=2
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'z')]=4

class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
for i in x:
    top=s.pop()
    
    s.push(top)
    cs=pda[cs,i]
    print("current state is :",cs)
    if i=='a' and top=='z':
        s.push(i)
        
      
    elif i=='a' and top=='a':
        s.push(i)
       
    elif i=='b' and top=='a':
        s.pop()
    elif i=='b' and top!='a':
        s.push(i)
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : aaabbb
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 3
# final state
# STRING ACCEPTED !

# %%
#test case:2 empty String
pda=dict()

pda[(0,'a')]=1
pda[(0,'b')]=4
pda[(0,'z')]=4
pda[(1,'a')]=1
pda[(1,'b')]=2
pda[(2,'a')]=4
pda[(2,'b')]=2
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'z')]=4

class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
for i in x:
    top=s.pop()
    
    s.push(top)
    cs=pda[cs,i]
    print("current state is :",cs)
    if i=='a' and top=='z':
        s.push(i)
        
      
    elif i=='a' and top=='a':
        s.push(i)
       
    elif i=='b' and top=='a':
        s.pop()
    elif i=='b' and top!='a':
        s.push(i)
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked :
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:3 string of type (ab)^n
pda=dict()

pda[(0,'a')]=1
pda[(0,'b')]=4
pda[(0,'z')]=4
pda[(1,'a')]=1
pda[(1,'b')]=2
pda[(2,'a')]=4
pda[(2,'b')]=2
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'z')]=4

class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
for i in x:
    top=s.pop()
    
    s.push(top)
    cs=pda[cs,i]
    print("current state is :",cs)
    if i=='a' and top=='z':
        s.push(i)
        
      
    elif i=='a' and top=='a':
        s.push(i)
       
    elif i=='b' and top=='a':
        s.pop()
    elif i=='b' and top!='a':
        s.push(i)
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : abab
# current state is : 1
# current state is : 2
# current state is : 4
# current state is : 4
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:4 string starting with b
pda=dict()

pda[(0,'a')]=1
pda[(0,'b')]=4
pda[(0,'z')]=4
pda[(1,'a')]=1
pda[(1,'b')]=2
pda[(2,'a')]=4
pda[(2,'b')]=2
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'z')]=4

class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
for i in x:
    top=s.pop()
    
    s.push(top)
    cs=pda[cs,i]
    print("current state is :",cs)
    if i=='a' and top=='z':
        s.push(i)
        
      
    elif i=='a' and top=='a':
        s.push(i)
       
    elif i=='b' and top=='a':
        s.pop()
    elif i=='b' and top!='a':
        s.push(i)
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : bbbaaa
# current state is : 4
# current state is : 4
# current state is : 4
# current state is : 4
# current state is : 4
# current state is : 4
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:4 number of b>a
pda=dict()

pda[(0,'a')]=1
pda[(0,'b')]=4
pda[(0,'z')]=4
pda[(1,'a')]=1
pda[(1,'b')]=2
pda[(2,'a')]=4
pda[(2,'b')]=2
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'z')]=4

class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
for i in x:
    top=s.pop()
    
    s.push(top)
    cs=pda[cs,i]
    print("current state is :",cs)
    if i=='a' and top=='z':
        s.push(i)
        
      
    elif i=='a' and top=='a':
        s.push(i)
       
    elif i=='b' and top=='a':
        s.pop()
    elif i=='b' and top!='a':
        s.push(i)
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : aaabbbb
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:5 number of a>b
pda=dict()

pda[(0,'a')]=1
pda[(0,'b')]=4
pda[(0,'z')]=4
pda[(1,'a')]=1
pda[(1,'b')]=2
pda[(2,'a')]=4
pda[(2,'b')]=2
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'z')]=4

class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
for i in x:
    top=s.pop()
    
    s.push(top)
    cs=pda[cs,i]
    print("current state is :",cs)
    if i=='a' and top=='z':
        s.push(i)
        
      
    elif i=='a' and top=='a':
        s.push(i)
       
    elif i=='b' and top=='a':
        s.pop()
    elif i=='b' and top!='a':
        s.push(i)
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : aaaabbb
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %% [markdown]
# Design a Program to create PDA machine that accept the well-formed brackets (parenthesis,curly braces and square brackets).

# %%
#test case:1 acceptable string
pda=dict()

pda[(0,'(')]=0
pda[(0,'{')]=0
pda[(0,'[')]=0
pda[(0,')')]=0
pda[(0,'}')]=0
pda[(0,']')]=0

pda[(0,'z')]=1


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked")
s.push('z')
cs=0
fs=1
for i in x:
    top=s.pop()
    s.push(top)
    if i=='(' or i=='{' or i== '[' :
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif i=='}' and top=='{':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i==')' and top=='(':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i==']' and top=='[':
        s.pop()
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked{{[()][]()}}
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 1
# final state
# STRING ACCEPTED !

# %%
#test case:2 acceptable String

pda=dict()

pda[(0,'(')]=0
pda[(0,'{')]=0
pda[(0,'[')]=0
pda[(0,')')]=0
pda[(0,'}')]=0
pda[(0,']')]=0

pda[(0,'z')]=1


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked")
s.push('z')
cs=0
fs=1
for i in x:
    top=s.pop()
    s.push(top)
    if i=='(' or i=='{' or i== '[' :
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif i=='}' and top=='{':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i==')' and top=='(':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i==']' and top=='[':
        s.pop()
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked{}[]()
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 1
# final state
# STRING ACCEPTED !

# %%
#test case:3 Unbalanced

pda=dict()

pda[(0,'(')]=0
pda[(0,'{')]=0
pda[(0,'[')]=0
pda[(0,')')]=0
pda[(0,'}')]=0
pda[(0,']')]=0

pda[(0,'z')]=1


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked")
s.push('z')
cs=0
fs=1
for i in x:
    top=s.pop()
    s.push(top)
    if i=='(' or i=='{' or i== '[' :
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif i=='}' and top=='{':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i==')' and top=='(':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i==']' and top=='[':
        s.pop()
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked{[](})
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# current state is : 0
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:4 Empty String

pda=dict()

pda[(0,'(')]=0
pda[(0,'{')]=0
pda[(0,'[')]=0
pda[(0,')')]=0
pda[(0,'}')]=0
pda[(0,']')]=0

pda[(0,'z')]=1


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)  
x=input("Enter the string to be checked")
s.push('z')
cs=0
fs=1
for i in x:
    top=s.pop()
    s.push(top)
    if i=='(' or i=='{' or i== '[' :
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif i=='}' and top=='{':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i==')' and top=='(':
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i==']' and top=='[':
        s.pop()
        
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked
# current state is : 1
# final state
# STRING ACCEPTED !

# %% [markdown]
# Design a PDA to accept WCWR where w is any string and WR is reverse of that string and C is a Special symbol.

# %%
#test case:1 acceptable String
pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4
class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)  
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0): 
        cs=pda[cs,i]
        print("current state is :",cs)
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)
if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : abaabcbaaba
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 3
# final state
# STRING ACCEPTED !

# %%
#test case:2 not reversed string

pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()
    
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0):
        
        cs=pda[cs,i]
        print("current state is :",cs)
   
        
        
   
y=s.pop()

cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : aabbabcaabbab
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# current state is : 2
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:3 string having exactly one c

pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()
    
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0):
        
        cs=pda[cs,i]
        print("current state is :",cs)
   
        
        
   
y=s.pop()

cs=pda[cs,y]
print("current state is :",cs)


if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : c
# current state is : 3
# final state
# STRING ACCEPTED !

# %%
#test case:4 number of c>one

pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4
class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda) 
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()
    
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0):
        cs=pda[cs,i]
        print("current state is :",cs) 
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)
if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : abbaccabba
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 2
# current state is : 4
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:5 string starting with c and c>1

pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4


class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)

    
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()
    
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0):
        
        cs=pda[cs,i]
        print("current state is :",cs) 
y=s.pop()

cs=pda[cs,y]
print("current state is :",cs)
if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : cc
# current state is : 4
# current state is : 4
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:6 Empty String

pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4
class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda)  
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()  
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0):
        
        cs=pda[cs,i]
        print("current state is :",cs)   
y=s.pop()

cs=pda[cs,y]
print("current state is :",cs)
if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked :
# current state is : 4
# stuck
# STRING NOT ACCEPTED !

# %%
#test case:7 String Without c

pda[(0,'a')]=1
pda[(0,'b')]=1
pda[(0,'z')]=4
pda[(0,'c')]=4
pda[(1,'a')]=1
pda[(1,'b')]=1
pda[(1,'c')]=2
pda[(2,'a')]=2
pda[(2,'b')]=2
pda[(2,'c')]=4
pda[(2,'z')]=3
pda[(4,'a')]=4
pda[(4,'b')]=4
pda[(4,'c')]=4
pda[(4,'z')]=4
class stack:
    def __init__ (self,pda):
        self.items=[]
    def push(self,item):
        self.items.append(item)
    def pop(self):
        return self.items.pop()
    def isempty(self):
        return self.items==[]
    def size(self):
        return len(self.items)
s=stack(pda) 
x=input("Enter the string to be checked : ")
s.push('z')
cs=0
fs=3
c_count=0
for i in x:
    top=s.pop()
    
    s.push(top)
    if i=='c' and len(x)==1:
        break
        
    if (i=='a' or i=='b') and top=='z' and cs==0:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='a' and top=='a' and cs==2 :
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='b' and top=='b' and cs==2:
        s.pop()
        cs=pda[cs,i]
        print("current state is :",cs)
        
      
    elif (i=='a' or i=='b') and (top=='a' or top=='b') and cs==1:
        s.push(i)
        cs=pda[cs,i]
        print("current state is :",cs)
       
    elif i=='c' and cs==1 and c_count==0:
        c_count=1
        cs=pda[cs,i]
        print("current state is :",cs)
    elif i=='c' and (cs!=1 or c_count!=0):
        
        cs=pda[cs,i]
        print("current state is :",cs) 
y=s.pop()
cs=pda[cs,y]
print("current state is :",cs)
if cs==fs:
    print("final state")
    print("STRING ACCEPTED !")
else:
    print("stuck")
    print("STRING NOT ACCEPTED !")
# Out:
# Enter the string to be checked : ababbaba
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# current state is : 1
# stuck
# STRING NOT ACCEPTED !
